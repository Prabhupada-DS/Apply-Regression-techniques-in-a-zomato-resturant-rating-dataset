# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("D:\\Dataset\\zomato.csv")

# %%
df.drop_duplicates(inplace=True)

# %%
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df['rate']=df['rate'].str.replace(" ","")
df['rate']=df['rate'].str.replace('-','NaN')
df['rate']=df['rate'].fillna('NaN')
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', 'NaN', '2.6/5', '3.4/5', '4.5/5',
#        '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5', '4.8/5',
#        '4.9/5', '2.1/5', '2.0/5', '1.8/5'], dtype=object)

# %%
df['rate'].shape
# Out:
# (51717,)

# %%
df.dropna(subset=['rate'],inplace=True)

# %%
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', 'NaN', '2.6/5', '3.4/5', '4.5/5',
#        '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5', '4.8/5',
#        '4.9/5', '2.1/5', '2.0/5', '1.8/5'], dtype=object)

# %%
df.shape
# Out:
# (51717, 17)

# %%
df['rate']=df['rate'].str.replace('NEW','NaN')

# %%
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NaN', '2.9/5', '3.5/5', '2.6/5', '3.4/5', '4.5/5',
#        '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5', '4.8/5',
#        '4.9/5', '2.1/5', '2.0/5', '1.8/5'], dtype=object)

# %%
df['rate']=df['rate'].str.replace('/5','')
df['rate']=df['rate'].str.replace('NaN','0')

# %%
df['rate'].unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', '0', '2.9', '3.5', '2.6',
#        '3.4', '4.5', '2.5', '2.7', '4.7', '2.4', '2.2', '2.3', '4.8',
#        '4.9', '2.1', '2.0', '1.8'], dtype=object)

# %%
df['rate']=df['rate'].astype(float)

# %%
df['rate']
# Out:
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
#         ...
# 51712    3.6
# 51713    0.0
# 51714    0.0
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 51717, dtype: float64

# %%
df['rate'].isna().sum()
# Out:
# 0

# %%
df['rate'].mean()
# Out:
# 2.981209273546415

# %%
df['rate'].median()
# Out:
# 3.6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         51717 non-null  float64
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
#  13  reviews_list                 51717 non-null  object
#  14  menu_item                    51717 non-null  object
#  15  listed_in(type)              51717 non-null  object
#  16  listed_in(city)              51717 non-null  object
# dtypes: float64(1), int64(1), object(15)
# memory usage: 4.1+ MB

# %%
df.isna().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                               0
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
del df['url']
del df['address']
del df['phone']
del df['reviews_list']
del df['menu_item']
del df['name']
df.head()
# Out:
#   online_order book_table  rate  votes      location            rest_type  \
# 0          Yes        Yes   4.1    775  Banashankari        Casual Dining
# 1          Yes         No   4.1    787  Banashankari        Casual Dining
# 2          Yes         No   3.8    918  Banashankari  Cafe, Casual Dining
# 3           No         No   3.7     88  Banashankari          Quick Bites
# 4           No         No   3.8    166  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people) listed_in(type)  \
# 0  North Indian, Mughlai, Chinese                         800          Buffet
# 1     Chinese, North Indian, Thai                         800          Buffet
# 2          Cafe, Mexican, Italian                         800          Buffet
# 3      South Indian, North Indian                         300          Buffet
# 4        North Indian, Rajasthani                         600          Buffet
#
#   listed_in(city)
# 0    Banashankari
# 1    Banashankari
# 2    Banashankari
# 3    Banashankari
# 4    Banashankari

# %%
df.isna().sum()
# Out:
# online_order                       0
# book_table                         0
# rate                               0
# votes                              0
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
df['votes']=df['votes'].astype('int32')

# %%
df['approx_cost(for two people)']=df['approx_cost(for two people)'].str.replace(",","")
df['approx_cost(for two people)'].unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1200', '350', '250',
#        '950', '1000', '1500', '1300', '199', '80', '1100', '160', '1600',
#        '230', '130', '50', '190', '1700', nan, '1400', '180', '1350',
#        '2200', '2000', '1800', '1900', '330', '2500', '2100', '3000',
#        '2800', '3400', '40', '1250', '3500', '4000', '2400', '2600',
#        '120', '1450', '469', '70', '3200', '60', '560', '240', '360',
#        '6000', '1050', '2300', '4100', '5000', '3700', '1650', '2700',
#        '4500', '140'], dtype=object)

# %%
df=df.rename(columns={"approx_cost(for two people)" : "avg_cost",
                      "listed_in(type)" : "meal_type", 
                      "listed_in(city)" : "city"})
df.head()
# Out:
#   online_order book_table  rate  votes      location            rest_type  \
# 0          Yes        Yes   4.1    775  Banashankari        Casual Dining
# 1          Yes         No   4.1    787  Banashankari        Casual Dining
# 2          Yes         No   3.8    918  Banashankari  Cafe, Casual Dining
# 3           No         No   3.7     88  Banashankari          Quick Bites
# 4           No         No   3.8    166  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines avg_cost meal_type          city
# 0  North Indian, Mughlai, Chinese      800    Buffet  Banashankari
# 1     Chinese, North Indian, Thai      800    Buffet  Banashankari
# 2          Cafe, Mexican, Italian      800    Buffet  Banashankari
# 3      South Indian, North Indian      300    Buffet  Banashankari
# 4        North Indian, Rajasthani      600    Buffet  Banashankari

# %%
df.dropna(subset=['avg_cost','rest_type'],inplace=True)

# %%
df['avg_cost']=df['avg_cost'].astype(int)

# %%
df.shape
# Out:
# (51167, 11)

# %%
df=df[df.cuisines.isna()==False]
df=df[df.rest_type.isna()==False]
df.isna().sum()
# Out:
# online_order        0
# book_table          0
# rate                0
# votes               0
# location            0
# rest_type           0
# dish_liked      27713
# cuisines            0
# avg_cost            0
# meal_type           0
# city                0
# dtype: int64

# %%
del df['location']

# %%
df.head()
# Out:
#   online_order book_table  rate  votes            rest_type  \
# 0          Yes        Yes   4.1    775        Casual Dining
# 1          Yes         No   4.1    787        Casual Dining
# 2          Yes         No   3.8    918  Cafe, Casual Dining
# 3           No         No   3.7     88          Quick Bites
# 4           No         No   3.8    166        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines  avg_cost meal_type          city
# 0  North Indian, Mughlai, Chinese       800    Buffet  Banashankari
# 1     Chinese, North Indian, Thai       800    Buffet  Banashankari
# 2          Cafe, Mexican, Italian       800    Buffet  Banashankari
# 3      South Indian, North Indian       300    Buffet  Banashankari
# 4        North Indian, Rajasthani       600    Buffet  Banashankari

# %% [markdown]
# Total number of online order resturants

# %%
plt.figure(figsize=(10,10))

sns.countplot(df['online_order'])
plt.title("number of restaurtants that take online_order",fontsize=25,color='blue')
plt.ylabel("Count",fontsize=20)
plt.xlabel("Online order",fontsize=20)
plt.show()

# %% [markdown]
# Total number of restaurants that have the option to book table

# %%
plt.figure(figsize=(10,10))

sns.countplot(df['book_table'])
plt.title("Number of restaurants that have the option to book table",fontsize=25,color='purple')
plt.ylabel("Count",fontsize=20)
plt.xlabel("Book Table",fontsize=20)
plt.show()

# %% [markdown]
# Meal Types in Resturant

# %%
plt.figure(figsize=(10,10))
ax =df.meal_type.value_counts()
labels=df['meal_type'].value_counts().index
plt.pie(ax,labels=labels,autopct='%.2f')
plt.title("Number of restaurants according to meal type",fontsize=25,color='purple')
plt.legend()
plt.show()

# %% [markdown]
# The resturant location in bangalore

# %%
plt.figure(figsize=(16,16))

ax=df.city.value_counts()[:10]
ax.plot(kind='pie',fontsize=20)

plt.title('number of restaurants in each location of banglore',fontsize=30,color='darkblue')
plt.show()

# %% [markdown]
# Resturant type in Bangalore

# %%
plt.figure(figsize=(10,10))

ax=df.rest_type.value_counts()[:10]
label=df['rest_type'].value_counts()[:10].index
ax.plot(kind='pie',labels=label,autopct='%.2f')

plt.title("Type of Restaurant in City",fontsize=20,color='darkgreen')
plt.show()

# %% [markdown]
# Average cost for two person

# %%
plt.figure(figsize=(10,10))

ax=df.avg_cost.value_counts()[:10]
label=df['avg_cost'].value_counts()[:10].index

plt.pie(ax,labels=label,autopct='%.2f')

plt.title("'Average cost for two person",fontsize=25)
plt.show()

# %% [markdown]
# Top dish liked in Bangalore

# %%
plt.figure(figsize=(10,10))
ax=df['dish_liked'].value_counts()[:10]
ax.plot(kind='bar')
plt.title("Top 10 dished_liked in Bangalore",fontsize=25,color='purple')
plt.show()

# %%
plt.figure(figsize=(10,10))
ax=df.dish_liked.value_counts()[:10]
label=df['dish_liked'].value_counts()[:10].index

plt.pie(ax,labels=label,autopct='%.2f')

plt.title("Top 10 dished_liked in Bangalore",fontsize=15)
plt.show()

# %% [markdown]
# Top 10 cusine

# %%
plt.figure(figsize=(10,10))

ax=df.cuisines.value_counts()[:10]
ax.plot(kind='bar')

plt.title("Top 10 Cuisine",fontsize=20)
plt.xticks(fontsize=20)
plt.show()

# %% [markdown]
# Online order according to ratings

# %%
plt.figure(figsize=(16,16))

sns.countplot(x=df['rate'],hue=df['online_order'])
plt.title("Rate VS Online order",fontsize=25)
plt.ylabel("Restaurants that Accept/Not Accepting online orders",fontsize=20)
plt.xlabel("rate",fontsize=20)
plt.show()

# %%
df.head()
# Out:
#   online_order book_table  rate  votes            rest_type  \
# 0          Yes        Yes   4.1    775        Casual Dining
# 1          Yes         No   4.1    787        Casual Dining
# 2          Yes         No   3.8    918  Cafe, Casual Dining
# 3           No         No   3.7     88          Quick Bites
# 4           No         No   3.8    166        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines  avg_cost meal_type          city
# 0  North Indian, Mughlai, Chinese       800    Buffet  Banashankari
# 1     Chinese, North Indian, Thai       800    Buffet  Banashankari
# 2          Cafe, Mexican, Italian       800    Buffet  Banashankari
# 3      South Indian, North Indian       300    Buffet  Banashankari
# 4        North Indian, Rajasthani       600    Buffet  Banashankari

# %%
df=df.drop(['dish_liked','meal_type'],axis=1)

# %%
df.head()
# Out:
#   online_order book_table  rate  votes            rest_type  \
# 0          Yes        Yes   4.1    775        Casual Dining
# 1          Yes         No   4.1    787        Casual Dining
# 2          Yes         No   3.8    918  Cafe, Casual Dining
# 3           No         No   3.7     88          Quick Bites
# 4           No         No   3.8    166        Casual Dining
#
#                          cuisines  avg_cost          city
# 0  North Indian, Mughlai, Chinese       800  Banashankari
# 1     Chinese, North Indian, Thai       800  Banashankari
# 2          Cafe, Mexican, Italian       800  Banashankari
# 3      South Indian, North Indian       300  Banashankari
# 4        North Indian, Rajasthani       600  Banashankari

# %% [markdown]
#  Convert categorical data into numerical data using LabelEncoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
list1=['online_order','book_table','rest_type','cuisines','city']
for i in list1:
    df[i]=le.fit_transform(df[i])

df.head()
# Out:
#    online_order  book_table  rate  votes  rest_type  cuisines  avg_cost  city
# 0             1           1   4.1    775         27      2145       800     1
# 1             1           0   4.1    787         27       947       800     1
# 2             1           0   3.8    918         22       761       800     1
# 3             0           0   3.7     88         78      2539       300     1
# 4             0           0   3.8    166         27      2174       600     1

# %%
df.shape
# Out:
# (51148, 8)

# %%
df.dropna(how='any',inplace=True)
df.shape
# Out:
# (51148, 8)

# %% [markdown]
# selecting features and split x,y value to fit models

# %%
features=df.drop(['rate'],axis=1)
label=df['rate'].values
label
# Out:
# array([4.1, 4.1, 3.8, ..., 0. , 4.3, 3.4])

# %% [markdown]
# Feature scaling

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
features=StandardScaler().fit(features).transform(features)
features
# Out:
# array([[ 0.82912014,  2.63270813,  0.60767491, ...,  0.97936006,
#          0.55501242, -1.59071902],
#        [ 0.82912014, -0.37983702,  0.62255425, ..., -0.58060705,
#          0.55501242, -1.59071902],
#        [ 0.82912014, -0.37983702,  0.78498706, ..., -0.82280562,
#          0.55501242, -1.59071902],
#        ...,
#        [-1.20609783, -0.37983702, -0.35328253, ..., -0.01157063,
#          3.28507103,  1.78898279],
#        [-1.20609783,  2.63270813, -0.06065549, ..., -0.01157063,
#          4.42259546,  1.78898279],
#        [-1.20609783, -0.37983702, -0.33716325, ...,  0.02358722,
#          2.14754661,  1.78898279]])

# %% [markdown]
# We splited out train and test set into 90% and 10% respectively

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge,Lasso,LogisticRegression
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(features,label,test_size=0.10,random_state=42)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((46033, 7), (5115, 7), (46033,), (5115,))

# %% [markdown]
# Now apply regression techniques to predict ratings

# %% [markdown]
# 1-Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg
lin_reg.fit(X_train,y_train)
print(lin_reg.score(X_train,y_train))
print(lin_reg.score(X_test,y_test))
lin_reg_pred=lin_reg.predict(X_test)
# Out:
# 0.21941176810528198
# 0.22180539678121935

# %%
from sklearn.metrics import r2_score
lin_reg_score=r2_score(y_test,lin_reg_pred)*100
print("Accuracy score for LR :",lin_reg_score)
# Out:
# Accuracy score for LR : 22.180539678121935

# %% [markdown]
# 2- Ridge Regression

# %%
from sklearn.linear_model import Ridge
rr=Ridge()
rr
rr.fit(X_train,y_train)
print(rr.score(X_train,y_train))
print(rr.score(X_test,y_test))
rr_pred=rr.predict(X_test)
# Out:
# 0.21941176803038998
# 0.22180514071771518

# %%
from sklearn.metrics import r2_score
rr_score=r2_score(y_test,rr_pred)*100
print("Accuracy score for RidgeR :",rr_score)
# Out:
# Accuracy score for RidgeR : 22.18051407177152

# %% [markdown]
# 3-Lasso

# %%
from sklearn.linear_model import Lasso
lr=Lasso()
lr
lr.fit(X_train,y_train)
print(lr.score(X_train,y_train))
print(lr.score(X_test,y_test))
lr_pred=lr.predict(X_test)
# Out:
# 0.0
# -1.976636728295844e-06

# %%
from sklearn.metrics import r2_score

lr_score=r2_score(y_test,lr_pred)*100
print("Accuracy score for LR :",lr_score)
# Out:
# Accuracy score for LR : -0.00019766367282958441

# %% [markdown]
# 4. Random Forest Regressor

# %%
rfr=RandomForestRegressor()
rfr
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators='warn',
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
rfr.fit(X_train,y_train)
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
print(rfr.score(X_train,y_train))
print(rfr.score(X_test,y_test))
# Out:
# 0.9961598451661884
# 0.9868295138248618

# %%
rfr_pred=rfr.predict(X_test)

# %%
from sklearn.metrics import r2_score

rfr_score=r2_score(y_test,rfr_pred)*100
print("Accuracy score for LR :",rfr_score)
# Out:
# Accuracy score for LR : 98.68295138248618

# %% [markdown]
# 5. Support Vector Regression

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(X_train,y_train)
print(svr.score(X_train,y_train))
print(svr.score(X_test,y_test))
svr_pred=svr.predict(X_test)
from sklearn.metrics import r2_score
svr_score=r2_score(y_test,svr_pred)*100
print("Accuracy score for LR :",svr_score)
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.23978999266026502
# 0.22530269272761663
# Accuracy score for LR : 22.53026927276166

# %%
pd.DataFrame({"Model Names":['Linear Reg','Ridge Reg','Lasso Reg','RandomForest Reg','Support Vector Reg'],
            "Accuracy socre":[lin_reg_score,rr_score,lr_score,rfr_score,svr_score]})
# Out:
#           Model Names  Accuracy socre
# 0          Linear Reg       22.180540
# 1           Ridge Reg       22.180514
# 2           Lasso Reg       -0.000198
# 3    RandomForest Reg       98.682951
# 4  Support Vector Reg       22.530269

# %% [markdown]
# Random forest regressor has highest accuracy score

# %% [markdown]
# Compare Actual rating with Random Forest Regressor new Predicted Rating

# %%
sample=pd.DataFrame({"Actual Ratin":y_test,
             "Predicted Rating":np.round(rfr_pred,2)})
sample
# Out:
#       Actual Ratin  Predicted Rating
# 0              3.2              3.22
# 1              3.7              3.53
# 2              0.0              0.00
# 3              3.1              3.14
# 4              3.3              3.36
# ...            ...               ...
# 5110           2.7              2.75
# 5111           3.5              3.42
# 5112           3.5              3.56
# 5113           4.1              4.05
# 5114           3.9              3.90
#
# [5115 rows x 2 columns]

# %% [markdown]
# predicted ratigs are not far from actual rating so model is good

# %%
##############
